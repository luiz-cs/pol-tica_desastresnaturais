# %%
#pip install requests
#pip install beautifulsoup4
#pip install pandas

# %%
import requests
import pandas as pd
import time
import os
import numpy as np
# Out:
# /tmp/ipykernel_5905/1139589405.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
#List of api URLs:
api_urls = [
    'https://sapl.capixaba.ac.leg.br/api/materia/materialegislativa/' , 
'https://sapl.cruzeirodosul.ac.leg.br/api/materia/materialegislativa/' , 
'https://sapl.feijo.ac.leg.br/api/materia/materialegislativa/' , 
'https://sapl.jordao.ac.leg.br/api/materia/materialegislativa/' , 
'https://sapl.manciolima.ac.leg.br/api/materia/materialegislativa/' , 
'https://sapl.manoelurbano.ac.leg.br/api/materia/materialegislativa/' , 
'https://sapl.placidodecastro.ac.leg.br/api/materia/materialegislativa/' , 
'https://sapl.portowalter.ac.leg.br/api/materia/materialegislativa/' , 
'https://sapl.riobranco.ac.leg.br/api/materia/materialegislativa/' , 
'https://sapl.rodriguesalves.ac.leg.br/api/materia/materialegislativa/' , 
'https://sapl.santarosadopurus.ac.leg.br/api/materia/materialegislativa/' , 
'https://sapl.senadorguiomard.ac.leg.br/api/materia/materialegislativa/' , 
'https://sapl.senamadureira.ac.leg.br/api/materia/materialegislativa/' , 
'https://sapl.craibas.al.leg.br/api/materia/materialegislativa/' , 
'https://sapl.delmirogouveia.al.leg.br/api/materia/materialegislativa/' , 
'https://sapl.flexeiras.al.leg.br/api/materia/materialegislativa/' , 
'https://sapl.maragogi.al.leg.br/api/materia/materialegislativa/' , 
'https://sapl.marechaldeodoro.al.leg.br/api/materia/materialegislativa/' , 
'https://sapl.murici.al.leg.br/api/materia/materialegislativa/' , 
'https://sapl.riolargo.al.leg.br/api/materia/materialegislativa/' , 
'https://sapl.amapa.ap.leg.br/api/materia/materialegislativa/' , 
'https://sapl.calcoene.ap.leg.br/api/materia/materialegislativa/' , 
'https://sapl.ferreiragomes.ap.leg.br/api/materia/materialegislativa/' , 
'https://sapl.laranjaldojari.ap.leg.br/api/materia/materialegislativa/' , 
'https://sapl.macapa.ap.leg.br/api/materia/materialegislativa/' , 
'https://sapl.oiapoque.ap.leg.br/api/materia/materialegislativa/' , 
'https://sapl.pedrabrancadoamapari.ap.leg.br/api/materia/materialegislativa/' , 
'https://sapl.portogrande.ap.leg.br/api/materia/materialegislativa/' , 
'https://sapl.santana.ap.leg.br/api/materia/materialegislativa/' , 
'https://sapl.tartarugalzinho.ap.leg.br/api/materia/materialegislativa/' , 
'https://sapl.alvaraes.am.leg.br/api/materia/materialegislativa/' , 
'https://sapl.apui.am.leg.br/api/materia/materialegislativa/' , 
'https://sapl.beruri.am.leg.br/api/materia/materialegislativa/' , 
'https://sapl.bocadoacre.am.leg.br/api/materia/materialegislativa/' , 
'https://sapl.caapiranga.am.leg.br/api/materia/materialegislativa/' , 
'https://sapl.coari.am.leg.br/api/materia/materialegislativa/' , 
'https://sapl.codajas.am.leg.br/api/materia/materialegislativa/' , 
'https://sapl.humaita.am.leg.br/api/materia/materialegislativa/' , 
'https://sapl.iranduba.am.leg.br/api/materia/materialegislativa/' , 
'https://sapl.itacoatiara.am.leg.br/api/materia/materialegislativa/' , 
'https://sapl.manacapuru.am.leg.br/api/materia/materialegislativa/' , 
'https://sapl.manicore.am.leg.br/api/materia/materialegislativa/' , 
'https://sapl.novoairao.am.leg.br/api/materia/materialegislativa/' , 
'https://sapl.parintins.am.leg.br/api/materia/materialegislativa/' , 
'https://sapl.saogabrieldacachoeira.am.leg.br/api/materia/materialegislativa/' , 
'https://sapl.tefe.am.leg.br/api/materia/materialegislativa/' , 
'https://sapl.urucara.am.leg.br/api/materia/materialegislativa/' , 
'https://sapl.alagoinhas.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.alcobaca.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.amargosa.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.araci.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.banzae.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.barra.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.barradaestiva.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.barradorocha.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.boquira.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.cachoeira.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.caetite.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.cafarnaum.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.conceicaodocoite.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.cotegipe.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.curaca.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.dariomeira.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.diasdavila.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.euclidesdacunha.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.feiradesantana.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.formosadoriopreto.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.gloria.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.guanambi.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.ibotirama.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.igrapiuna.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.ilheus.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.ipiau.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.itaberaba.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.itabuna.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.itacare.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.itagiba.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.itanhem.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.itapetinga.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.jequie.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.juazeiro.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.lapao.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.manoelvitorino.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.maracas.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.matadesaojoao.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.morrodochapeu.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.paratinga.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.paripiranga.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.pauloafonso.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.pilaoarcado.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.uaua.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.vitoriadaconquista.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.xiquexique.ba.leg.br/api/materia/materialegislativa/' , 
'https://sapl.amontada.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.aquiraz.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.aracati.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.ararenda.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.assare.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.banabuiu.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.barro.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.beberibe.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.belacruz.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.campossales.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.caninde.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.caririacu.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.carnaubal.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.cascavel.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.caucaia.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.eusebio.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.fariasbrito.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.fortaleza.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.fortim.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.horizonte.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.ibicuitinga.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.icapui.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.ipueiras.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.iraucuba.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.itaicaba.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.itapaje.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.maracanau.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.mauriti.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.mombaca.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.moradanova.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.novaolinda.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.pacajus.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.pacatuba.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.pacoti.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.palmacia.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.poranga.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.quixelo.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.salitre.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.santanadoacarau.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.saogoncalodoamarante.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.taua.ce.leg.br/api/materia/materialegislativa/' , 
'https://sapl.alegre.es.leg.br/api/materia/materialegislativa/' , 
'https://sapl.aracruz.es.leg.br/api/materia/materialegislativa/' , 
'https://sapl.baixoguandu.es.leg.br/api/materia/materialegislativa/' , 
'https://sapl.cachoeirodeitapemirim.es.leg.br/api/materia/materialegislativa/' , 
'https://sapl.conceicaodabarra.es.leg.br/api/materia/materialegislativa/' , 
'https://sapl.domingosmartins.es.leg.br/api/materia/materialegislativa/' , 
'https://sapl.guarapari.es.leg.br/api/materia/materialegislativa/' , 
'https://sapl.ibatiba.es.leg.br/api/materia/materialegislativa/' , 
'https://sapl.ibitirama.es.leg.br/api/materia/materialegislativa/' , 
'https://sapl.iconha.es.leg.br/api/materia/materialegislativa/' , 
'https://sapl.itapemirim.es.leg.br/api/materia/materialegislativa/' , 
'https://sapl.iuna.es.leg.br/api/materia/materialegislativa/' , 
'https://sapl.jaguare.es.leg.br/api/materia/materialegislativa/' , 
'https://sapl.joaoneiva.es.leg.br/api/materia/materialegislativa/' , 
'https://sapl.linhares.es.leg.br/api/materia/materialegislativa/' , 
'https://sapl.marechalfloriano.es.leg.br/api/materia/materialegislativa/' , 
'https://sapl.marilandia.es.leg.br/api/materia/materialegislativa/' , 
'https://sapl.montanha.es.leg.br/api/materia/materialegislativa/' , 
'https://sapl.mucurici.es.leg.br/api/materia/materialegislativa/' , 
'https://sapl.pedrocanario.es.leg.br/api/materia/materialegislativa/' , 
'https://sapl.pinheiros.es.leg.br/api/materia/materialegislativa/' , 
'https://sapl.rionovodosul.es.leg.br/api/materia/materialegislativa/' , 
'https://sapl.santaleopoldina.es.leg.br/api/materia/materialegislativa/' , 
'https://sapl.santamariadejetiba.es.leg.br/api/materia/materialegislativa/' , 
'https://sapl.saogabrieldapalha.es.leg.br/api/materia/materialegislativa/' , 
'https://sapl.saojosedocalcado.es.leg.br/api/materia/materialegislativa/' , 
'https://sapl.saomateus.es.leg.br/api/materia/materialegislativa/' , 
'https://sapl.vendanovadoimigrante.es.leg.br/api/materia/materialegislativa/' , 
'https://sapl.viana.es.leg.br/api/materia/materialegislativa/' , 
'https://sapl.vilavelha.es.leg.br/api/materia/materialegislativa/' , 
'https://sapl.acreuna.go.leg.br/api/materia/materialegislativa/' , 
'https://sapl.altoparaisodegoias.go.leg.br/api/materia/materialegislativa/' , 
'https://sapl.alvoradadonorte.go.leg.br/api/materia/materialegislativa/' , 
'https://sapl.anapolis.go.leg.br/api/materia/materialegislativa/' , 
'https://sapl.aparecidadoriodoce.go.leg.br/api/materia/materialegislativa/' , 
'https://sapl.apore.go.leg.br/api/materia/materialegislativa/' , 
'https://sapl.cacu.go.leg.br/api/materia/materialegislativa/' , 
'https://sapl.campinorte.go.leg.br/api/materia/materialegislativa/' , 
'https://sapl.campoalegredegoias.go.leg.br/api/materia/materialegislativa/' , 
'https://sapl.camposbelos.go.leg.br/api/materia/materialegislativa/' , 
'https://sapl.catalao.go.leg.br/api/materia/materialegislativa/' , 
'https://sapl.cristianopolis.go.leg.br/api/materia/materialegislativa/' , 
'https://sapl.crixas.go.leg.br/api/materia/materialegislativa/' , 
'https://sapl.formosa.go.leg.br/api/materia/materialegislativa/' , 
'https://sapl.inaciolandia.go.leg.br/api/materia/materialegislativa/' , 
'https://sapl.ipameri.go.leg.br/api/materia/materialegislativa/' , 
'https://sapl.luziania.go.leg.br/api/materia/materialegislativa/' , 
'https://sapl.matrincha.go.leg.br/api/materia/materialegislativa/' , 
'https://sapl.moipora.go.leg.br/api/materia/materialegislativa/' , 
'https://sapl.novaaurora.go.leg.br/api/materia/materialegislativa/' , 
'https://sapl.novaveneza.go.leg.br/api/materia/materialegislativa/' , 
'https://sapl.orizona.go.leg.br/api/materia/materialegislativa/' , 
'https://sapl.palmelo.go.leg.br/api/materia/materialegislativa/' , 
'https://sapl.palminopolis.go.leg.br/api/materia/materialegislativa/' , 
'https://sapl.paranaiguara.go.leg.br/api/materia/materialegislativa/' , 
'https://sapl.pirenopolis.go.leg.br/api/materia/materialegislativa/' , 
'https://sapl.piresdorio.go.leg.br/api/materia/materialegislativa/' , 
'https://sapl.pontalina.go.leg.br/api/materia/materialegislativa/' , 
'https://sapl.porangatu.go.leg.br/api/materia/materialegislativa/' , 
'https://sapl.quirinopolis.go.leg.br/api/materia/materialegislativa/' , 
'https://sapl.saomigueldoaraguaia.go.leg.br/api/materia/materialegislativa/' , 
'https://sapl.saomigueldopassaquatro.go.leg.br/api/materia/materialegislativa/' , 
'https://sapl.saosimao.go.leg.br/api/materia/materialegislativa/' , 
'https://sapl.
sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.doiscorregos.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.embuguacu.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.espiritosantodoturvo.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.fernandopolis.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.fernao.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.galia.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.garca.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.guara.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.guaranta.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.guariba.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.guarulhos.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.guatapara.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.iaras.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.ibiuna.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.igarapava.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.iguape.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.ilhacomprida.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.indiapora.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.ipigua.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.itabera.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.itai.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.itajobi.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.itaporanga.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.itapui.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.ituverava.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.jacupiranga.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.jardinopolis.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.jumirim.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.juquitiba.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.laranjalpaulista.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.lavrinhas.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.leme.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.lencoispaulista.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.lourdes.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.mairipora.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.meridiano.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.miracatu.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.mococa.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.mogidascruzes.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.montealto.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.montemor.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.novaodessa.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.ourinhos.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.parapua.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.pariqueraacu.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.parisi.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.pedreira.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.piedade.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.piraporadobomjesus.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.planalto.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.pompeia.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.pontal.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.portofeliz.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.pradopolis.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.praiagrande.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.queiroz.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.rafard.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.registro.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.ribeiraogrande.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.sagres.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.salesoliveira.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.salmourao.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.santacruzdaspalmeiras.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.santaisabel.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.santoantoniodaalegria.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.saojoaodaboavista.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.saojosedobarreiro.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.saovicente.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.sarutaia.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.serrana.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.severinia.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.socorro.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.taguai.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.tapiratiba.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.taquaral.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.taquarituba.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.tiete.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.urupes.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.veracruz.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.vinhedo.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.votorantim.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.zacarias.sp.leg.br/api/materia/materialegislativa/' , 
'https://sapl.aracaju.se.leg.br/api/materia/materialegislativa/' , 
'https://sapl.barradoscoqueiros.se.leg.br/api/materia/materialegislativa/' , 
'https://sapl.estancia.se.leg.br/api/materia/materialegislativa/' , 
'https://sapl.gararu.se.leg.br/api/materia/materialegislativa/' , 
'https://sapl.grachocardoso.se.leg.br/api/materia/materialegislativa/' , 
'https://sapl.lagarto.se.leg.br/api/materia/materialegislativa/' , 
'https://sapl.laranjeiras.se.leg.br/api/materia/materialegislativa/' , 
'https://sapl.malhadadosbois.se.leg.br/api/materia/materialegislativa/' , 
'https://sapl.nossasenhoradelourdes.se.leg.br/api/materia/materialegislativa/' , 
'https://sapl.pirambu.se.leg.br/api/materia/materialegislativa/' , 
'https://sapl.pocoverde.se.leg.br/api/materia/materialegislativa/' , 
'https://sapl.santoamarodasbrotas.se.leg.br/api/materia/materialegislativa/' , 
'https://sapl.saodomingos.se.leg.br/api/materia/materialegislativa/' , 
'https://sapl.abreulandia.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.aliancadotocantins.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.alvorada.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.araguacema.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.araguacu.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.araguana.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.araguatins.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.arapoema.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.babaculandia.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.barrolandia.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.brejinhodenazare.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.cariridotocantins.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.caseara.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.chapadadanatividade.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.chapadadeareia.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.colmeia.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.coutodemagalhaes.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.crixasdotocantins.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.divinopolisdotocantins.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.doisirmaosdotocantins.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.duere.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.fatima.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.figueiropolis.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.formosodoaraguaia.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.guarai.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.gurupi.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.ipueiras.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.itaporadotocantins.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.lagoadaconfusao.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.lavandeira.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.marianopolisdotocantins.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.montedocarmo.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.montesantodotocantins.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.oliveiradefatima.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.palmas.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.palmeirante.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.pedroafonso.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.peixe.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.portonacional.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.presidentekennedy.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.riodosbois.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.riosono.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.sandolandia.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.santaritadotocantins.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.saosalvadordotocantins.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.saovaleriodanatividade.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.sucupira.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.tabocao.to.leg.br/api/materia/materialegislativa/' , 
'https://sapl.talisma.to.leg.br/api/materia/materialegislativa/' , 
]

# %%
# Function to fetch data from API
def fetch_data(api_url):
    try:
        response = requests.get(api_url)  # Send a GET request to the API URL
        response.raise_for_status()  # Raise an exception for bad response status codes
        return response.json()  # Return JSON data if the request is successful
    except Exception as e:
        print(f"Failed to fetch data from {api_url}: {e}")
        return None

# %%
# Function to save data for each API URL
def save_data(data, api_url, page_number):
    if data is None:  # Check if data is None
        print(f"No data to save for {api_url}, page {page_number}.")
        return  # Return early if data is None
    city_name = api_url.split(".")[1]  # Extract city name from the URL
    city_file = f"{city_name}_data.csv"  # File name for the city data
    city_df = pd.DataFrame(data)  # Create a DataFrame from the fetched data
    if os.path.exists(city_file):  # If the file already exists, append data to it
        city_df.to_csv(city_file, mode='a', header=False, index=False)
    else:  # If the file doesn't exist, create it and write data to it
        city_df.to_csv(city_file, index=False)

# %%
# Function to iterate through pages and fetch data
def fetch_all_data(api_url, start_page=1):
    all_data = []  # Initialize an empty list to store all data
    next_url = api_url  # Initialize the next URL to the provided API URL
    page_number = start_page  # Initialize the page number
    while next_url:
        print(f"Processing page {page_number} of {api_url}...")  # Print current page being processed
        data = fetch_data(next_url)  # Fetch data from the current URL
        if not data:  # If data retrieval fails, exit the loop
            break
        all_data.extend(data["results"])  # Extend the list with data from the current page
        next_url = data["pagination"]["links"].get("next")  # Get the URL for the next page, if available
        if next_url:
            time.sleep(0.2)  # Wait for X seconds before making the next request to respect API limits
            page_number += 1  # Increment the page number
            # Save data for each page
            save_data(data["results"], api_url, page_number)
            # Update progress after processing each page
            with open(progress_file, "w") as file:
                file.write(f"{i}\n")  # Write the last processed API URL
                file.write(f"{page_number}\n")  # Write the last processed page
                file.write(next_url if next_url else "")  # Write the last processed next URL
    return all_data  # Return the collected data

# %%
# Initialize an empty DataFrame
final_df = pd.DataFrame()

# Check if progress file exists
progress_file = "progress.txt"
if os.path.exists(progress_file):
    with open(progress_file, "r") as file:
        progress_data = file.readlines()
    last_processed_index = int(progress_data[0].strip())  # Read the index of the last processed API URL
    last_processed_page = int(progress_data[1].strip())  # Read the last processed page
    last_processed_next_url = progress_data[2].strip()  # Read the last processed next URL
else:
    last_processed_index = 0  # If the progress file doesn't exist, start from the beginning
    last_processed_page = 1  # Start from the first page
    last_processed_next_url = api_urls[0]

# Loop through each API URL starting from the last processed index
for i in range(last_processed_index, len(api_urls)):
    api_url = api_urls[i]
    print(f"Processing {api_url}...")  # Print current API URL being processed
    city_name = api_url.split(".")[1]  # Extract city name from the URL
    if last_processed_next_url == api_url:
        city_data = fetch_all_data(api_url, start_page=last_processed_page)  # Fetch data from the API URL starting from the last processed page
    else:
        city_data = fetch_all_data(last_processed_next_url, start_page=last_processed_page)  # Fetch data from the API URL
    if city_data:
        city_df = pd.DataFrame(city_data)
        city_df["City"] = city_name
        city_df["API_URL"] = api_url
        city_df.to_csv(f"{city_name}_data.csv", index=False)
        final_df = pd.concat([final_df, city_df], ignore_index=True)
    # Update last processed next URL and page for progress
    if i < len(api_urls) - 1:  # If not the last URL in the list
        last_processed_next_url = api_urls[i + 1]  # Update last processed next URL
        last_processed_page = 1  # Reset page number for the next URL
# Out:
# Processing https://sapl.votorantim.sp.leg.br/api/materia/materialegislativa/...
# Processing page 996 of https://sapl.votorantim.sp.leg.br/api/materia/materialegislativa/?page=996...
# Processing page 997 of https://sapl.votorantim.sp.leg.br/api/materia/materialegislativa/?page=996...
# Processing page 998 of https://sapl.votorantim.sp.leg.br/api/materia/materialegislativa/?page=996...
# Processing page 999 of https://sapl.votorantim.sp.leg.br/api/materia/materialegislativa/?page=996...
# Processing page 1000 of https://sapl.votorantim.sp.leg.br/api/materia/materialegislativa/?page=996...
# Processing page 1001 of https://sapl.votorantim.sp.leg.br/api/materia/materialegislativa/?page=996...
# Processing page 1002 of https://sapl.votorantim.sp.leg.br/api/materia/materialegislativa/?page=996...
# Processing page 1003 of https://sapl.votorantim.sp.leg.br/api/materia/materialegislativa/?page=996...
# ...

# %%
# Save the final DataFrame
# List to store DataFrames from each CSV file
allcities = []

# Iterate over each file in the folder
for file_name in os.listdir('SAPL-Cidades'):
    if file_name.endswith(".csv"):  # Check if the file is a CSV file
        file_path = os.path.join('SAPL-Cidades', file_name)  # Get the full file path
        onecity = pd.read_csv(file_path, dtype=str)  # Read the CSV file into a DataFrame
        allcities.append(onecity)  # Append the DataFrame to the list

# Concatenate all DataFrames into a single one
merged_df = pd.concat(allcities, ignore_index=True)
merged_df.to_csv("ProjCidades.csv", index = False)
